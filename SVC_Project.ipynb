# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import files
upload=files.upload()
data = pd.read_csv("default of credit card clients.csv")
# Out:
#      <input type="file" id="files-7c97f074-f93e-4a06-b430-203990c11588" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7c97f074-f93e-4a06-b430-203990c11588">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9',
#        'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X19',
#        'X20', 'X21', 'X22', 'X23', 'Y'],
#       dtype='object')

# %%
data = data[data.index != 0]

# %%
data.head()
# Out:
#   Unnamed: 0      X1 X2 X3 X4  X5  X6 X7  X8  X9  ...    X15    X16    X17  \
# 1          1   20000  2  2  1  24   2  2  -1  -1  ...      0      0      0
# 2          2  120000  2  2  2  26  -1  2   0   0  ...   3272   3455   3261
# 3          3   90000  2  2  2  34   0  0   0   0  ...  14331  14948  15549
# 4          4   50000  2  2  1  37   0  0   0   0  ...  28314  28959  29547
# 5          5   50000  1  2  1  57  -1  0  -1   0  ...  20940  19146  19131
#
#     X18    X19    X20   X21   X22   X23  Y
# 1     0    689      0     0     0     0  1
# 2     0   1000   1000  1000     0  2000  1
# 3  1518   1500   1000  1000  1000  5000  0
# 4  2000   2019   1200  1100  1069  1000  0
# 5  2000  36681  10000  9000   689   679  0
#
# [5 rows x 25 columns]

# %%
#Check for missing values
print(data.isnull().sum())
# Out:
# Unnamed: 0    0
# X1            0
# X2            0
# X3            0
# X4            0
# X5            0
# X6            0
# X7            0
# X8            0
# X9            0
# X10           0
# X11           0
# X12           0
# X13           0
# X14           0
# X15           0
# X16           0
# X17           0
# X18           0
# X19           0
# X20           0
# X21           0
# X22           0
# X23           0
# Y             0
# dtype: int64

# %%
# Display column names to check for correctness
print(data.columns)
# Out:
# Index(['Unnamed: 0', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9',
#        'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X19',
#        'X20', 'X21', 'X22', 'X23', 'Y'],
#       dtype='object')

# %%
# Separate features and target variable
X = data.drop(columns=['Y'])  # Assuming 'Y' is the target column
y = data['Y']

# Convert non-numeric columns in X to numeric
X = X.apply(pd.to_numeric, errors='coerce')

# Check the data types of columns in X
print(X.dtypes)

# Filter out rows where 'y' is not numeric
df_numeric = data[data['Y'].apply(lambda value: isinstance(value, (int, float)))]

# Convert 'Y' to integer
y = df_numeric['Y'].astype(int)

# Display updated X and y
print(X.head())
print(y.head())
# Out:
# Unnamed: 0    int64
# X1            int64
# X2            int64
# X3            int64
# X4            int64
# X5            int64
# X6            int64
# X7            int64
# X8            int64
# X9            int64
# X10           int64
# X11           int64
# X12           int64
# X13           int64
# X14           int64
# X15           int64
# X16           int64
# X17           int64
# X18           int64
# X19           int64
# X20           int64
# X21           int64
# X22           int64
# X23           int64
# dtype: object
#    Unnamed: 0      X1  X2  X3  X4  X5  X6  X7  X8  X9  ...    X14    X15  \
# 1           1   20000   2   2   1  24   2   2  -1  -1  ...    689      0
# 2           2  120000   2   2   2  26  -1   2   0   0  ...   2682   3272
# 3           3   90000   2   2   2  34   0   0   0   0  ...  13559  14331
# 4           4   50000   2   2   1  37   0   0   0   0  ...  49291  28314
# 5           5   50000   1   2   1  57  -1   0  -1   0  ...  35835  20940
#
# ...
